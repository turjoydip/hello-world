# %% [markdown]
# <a href="https://colab.research.google.com/github/turjoydip/hello-world/blob/main/Lambda_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def pow(a, b):
    return a**b # ** means to the power

# %%
pow(3, 2)
# Out:
# 9

# %%
#write this in lambda function way

pow = lambda a, b : a**b

# %%
pow(3, 2)
# Out:
# 9

# %%
# write a lambda function which is add numbers

add = lambda a, b: a + b

# %%
add(10, 20)
# Out:
# 30

# %%
number = lambda *args : print(args)

# %%
number(1, 2, 3, 4)
# Out:
# (1, 2, 3, 4)

# %%
number = lambda *args : [x * x for x in args]

# %%
number(1, 2, 3 ,4, 5)
# Out:
# [1, 4, 9, 16, 25]

# %%
finding_max = lambda x,y : x if x>y else y

# %%
finding_max(2, 3)
# Out:
# 3

# %%
# lamdba arguments : expressions
