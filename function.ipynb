# %% [markdown]
# <a href="https://colab.research.google.com/github/turjoydip/hello-world/blob/main/function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def str():
    return "My name is Tareque "

# %%
str() + "emdadul"
# Out:
# 'My name is Tareque emdadul'

# %%
def test():
    return "string", 23, 34.5, [1,2,3,5]

# %%
test()
# Out:
# ('string', 23, 34.5, [1, 2, 3, 5])

# %%
a, b, c, d = test()

# %%
a
# Out:
# 'string'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 34.5

# %%
d
# Out:
# [1, 2, 3, 5]

# %%
def concatinate(a, b):
    return a+b

# %%
concatinate(2,3)
# Out:
# 5

# %%
concatinate("Emdadul ", "Tareque")
# Out:
# 'Emdadul Tareque'

# %%
concatinate([1, 2, 3, 4], [5, 6, 7])
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
concatinate((1, 2, 3, 4), (5, 6, 7))
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
def find_integer(lst):
    li = []
    for i in lst:
        if type(i) == int or type(i) == float:
            li.append(i)
    return li

# %%
lst = [1, 2, 3, 4, "Emdadul", "Tarque", [1, 2, 3, 4, 5]]

# %%
find_integer(lst)
# Out:
# [1, 2, 3, 4]

# %%
def find_int(lst):
    """This is my function to extract num data from list"""
    li = []

    for i in lst:
        if type(i) == list:
            for j in i:
                if type(j) == int or type(j) == float:
                    li.append(j)
        else:
            if type(i) == int or type(i) == float:
                    li.append(i)
    return li

# %%
find_int(lst)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4, 5]

# %%
# যদি একটা ফাংশনের মধ্যে যত ইচ্ছা তত আর্গুমেন্ট পাস করতে চাই
def test(*args):
    return args

# %%
test(1,2,3,4)
# Out:
# (1, 2, 3, 4)

# %%
def test1(*a):
    return a

# %%
test1(2, 3, 4, 5,["a", "b", "c"])
# Out:
# (2, 3, 4, 5, ['a', 'b', 'c'])

# %%
def test2(*args):
    li = []
    for i in args:
        li.append(i)
    return li

# %%
test2(1, 2, 3, 4)
# Out:
# [1, 2, 3, 4]

# %%
def test4 (*args, a):
    return args, a

# %%
test4(2, 3, 4,a=1)
# Out:
# ((2, 3, 4), 1)

# %%
test4(1, 2, 3, 4, a = 23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def test5(c,d,a = 10, b = 20):
    return a,b,c,d

# %%
def test5(c, d, a = 10, b = 20):
    return a, b, c, d

# %%
test5(2, 4)
# Out:
# (10, 20, 2, 4)

# %%
test5(1, 2, 3, 4)
# Out:
# (3, 4, 1, 2)

# %%
test5(1, 2, a = 3)
# Out:
# (3, 20, 1, 2)

# %%
#if i want to input/output as dictionary

def test6(**kwargs):
    return kwargs

# %%
test6(a = 10, b = 20, c = [1, 2, 3, 4], d = ("emdadul", "Tareque"))
# Out:
# {'a': 10, 'b': 20, 'c': [1, 2, 3, 4], 'd': ('emdadul', 'Tareque')}

# %%
def test7(*a, **kwargs):
    return a, kwargs
